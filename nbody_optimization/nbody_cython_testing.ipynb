# %%
# %load_ext Cython
import pyximport
pyximport.install()
# Out:
# (None, <pyximport.pyximport.PyxImporter at 0x1d067c3c4c8>)

# %%
import nbody_cython
# Out:
# ---------------------------------------------------------------------------
# DistutilsExecError                        Traceback (most recent call last)
# ~\miniconda3\lib\distutils\cygwinccompiler.py in _compile(self, obj, src, ext, cc_args, extra_postargs, pp_opts)
#     172                 self.spawn(self.compiler_so + cc_args + [src, '-o', obj] +
# --> 173                            extra_postargs)
#     174             except DistutilsExecError as msg:
#
# ~\miniconda3\lib\distutils\ccompiler.py in spawn(self, cmd)
#     909     def spawn(self, cmd):
# --> 910         spawn(cmd, dry_run=self.dry_run)
#     911
#
# ~\miniconda3\lib\distutils\spawn.py in spawn(cmd, search_path, verbose, dry_run)
#      37     elif os.name == 'nt':
# ---> 38         _spawn_nt(cmd, search_path, dry_run=dry_run)
#      39     else:
#
# ~\miniconda3\lib\distutils\spawn.py in _spawn_nt(cmd, search_path, verbose, dry_run)
#      80             raise DistutilsExecError(
# ...
